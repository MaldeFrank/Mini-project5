# %%
import pandas as pd

# %%
na_values = ['NaN','Na','N/A']
df = pd.read_csv('cleaned_data_before_numeric_change.csv',na_values=na_values)

# %%
df
# Out:
#                        id    host_id  host_acceptance_rate host_is_superhost  \
# 0      772195193586734462  139504671                  57.0                 f
# 1      993508926988263521  540024469                 100.0                 f
# 2      973046361084511805  413314931                  57.0                 f
# 3                52551491   36416123                  48.0                 f
# 4      723099448414722172    5049349                  79.0                 t
# ...                   ...        ...                   ...               ...
# 18226  899314240743700953  516545031                  92.0                 f
# 18227  894209151571063412   87341967                 100.0                 t
# 18228  882414557986654201  378586472                  33.0                 f
# 18229            50437911   90546144                  94.0                 t
# 18230  899770214952158073  473758988                  63.0                 f
#
#        host_total_listings_count host_has_profile_pic host_identity_verified  \
# 0                            2.0                    t                      t
# 1                            1.0                    t                      f
# 2                            1.0                    t                      t
# 3                            1.0                    t                      t
# 4                            3.0                    t                      t
# ...                          ...                  ...                    ...
# 18226                        1.0                    f                      t
# 18227                        1.0                    t                      t
# 18228                        1.0                    t                      t
# 18229                        1.0                    t                      t
# 18230                        1.0                    t                      t
#
#           neighbourhood_cleansed                property_type  \
# 0                       Indre By  Private room in rental unit
# 1                      Amager st           Entire rental unit
# 2                    Amager Vest           Entire rental unit
# 3      Vesterbro-Kongens Enghave                 Entire condo
# 4      Vesterbro-Kongens Enghave                 Entire condo
# ...                          ...                          ...
# 18226  Vesterbro-Kongens Enghave           Entire rental unit
# 18227              Frederiksberg           Entire rental unit
# 18228                Amager Vest           Entire rental unit
# 18229  Vesterbro-Kongens Enghave           Entire rental unit
# 18230                   Nørrebro           Entire rental unit
#
#              room_type  ...  bathrooms_text beds        price  minimum_nights  \
# 0         Private room  ...   1 shared bath  1.0  1320.467531               5
# 1      Entire home/apt  ...          1 bath  1.0   860.000000               2
# 2      Entire home/apt  ...          1 bath  1.0  1000.000000               2
# 3      Entire home/apt  ...          1 bath  1.0  1200.000000               2
# 4      Entire home/apt  ...          1 bath  3.0  1400.000000               2
# ...                ...  ...             ...  ...          ...             ...
# 18226  Entire home/apt  ...          1 bath  1.0  1320.467531               2
# 18227  Entire home/apt  ...          1 bath  1.0  1320.467531               1
# 18228  Entire home/apt  ...          1 bath  3.0  1320.467531               3
# 18229  Entire home/apt  ...          1 bath  1.0  1873.000000               4
# 18230  Entire home/apt  ...          1 bath  1.0  1320.467531               7
#
#        maximum_nights  availability_365  number_of_reviews  \
# 0                  12                 0                  0
# 1                  20                25                  9
# 2                  60               107                  7
# 3                   7               178                 16
# 4                  30               118                 16
# ...               ...               ...                ...
# 18226               7                 0                  6
# 18227             365                 0                 11
# 18228             365                 0                  0
# 18229              60               222                 27
# 18230            1125                 0                  4
#
#        review_scores_rating  instant_bookable reviews_per_month
# 0                  4.818525                 f          0.733238
# 1                  4.670000                 f          3.330000
# 2                  4.860000                 f          3.750000
# 3                  5.000000                 f          0.590000
# 4                  4.940000                 f          1.210000
# ...                     ...               ...               ...
# 18226              4.830000                 t          0.930000
# 18227              4.820000                 t          1.530000
# 18228              4.818525                 f          0.733238
# 18229              4.960000                 f          0.910000
# 18230              5.000000                 f          0.570000
#
# [18231 rows x 21 columns]

# %% [markdown]
# Feature engineering price intervals.

# %%
num_bins = [0,100,200,500,800,1000,2000,10000,100000]

df['price_intervals'] = pd.cut(df['price'],bins=num_bins)

# %%
df.isnull().sum()
# Out:
# id                           0
# host_id                      0
# host_acceptance_rate         0
# host_is_superhost            0
# host_total_listings_count    0
# host_has_profile_pic         0
# host_identity_verified       0
# neighbourhood_cleansed       0
# property_type                0
# room_type                    0
# accommodates                 0
# bathrooms_text               0
# beds                         0
# price                        0
# minimum_nights               0
# maximum_nights               0
# availability_365             0
# number_of_reviews            0
# review_scores_rating         0
# instant_bookable             0
# reviews_per_month            0
# price_intervals              0
# dtype: int64

# %% [markdown]
# Taking parameters i wish to check for which is property_type, room_type, bathrooms_text, beds, price

# %%
selected_columns = ['neighbourhood_cleansed','property_type', 'room_type', 'bathrooms_text','price_intervals']

selection_df = df[selected_columns].copy()

# %%
selection_df
# Out:
#           neighbourhood_cleansed                property_type  \
# 0                       Indre By  Private room in rental unit
# 1                      Amager st           Entire rental unit
# 2                    Amager Vest           Entire rental unit
# 3      Vesterbro-Kongens Enghave                 Entire condo
# 4      Vesterbro-Kongens Enghave                 Entire condo
# ...                          ...                          ...
# 18226  Vesterbro-Kongens Enghave           Entire rental unit
# 18227              Frederiksberg           Entire rental unit
# 18228                Amager Vest           Entire rental unit
# 18229  Vesterbro-Kongens Enghave           Entire rental unit
# 18230                   Nørrebro           Entire rental unit
#
#              room_type bathrooms_text price_intervals
# 0         Private room  1 shared bath    (1000, 2000]
# 1      Entire home/apt         1 bath     (800, 1000]
# 2      Entire home/apt         1 bath     (800, 1000]
# 3      Entire home/apt         1 bath    (1000, 2000]
# 4      Entire home/apt         1 bath    (1000, 2000]
# ...                ...            ...             ...
# 18226  Entire home/apt         1 bath    (1000, 2000]
# 18227  Entire home/apt         1 bath    (1000, 2000]
# 18228  Entire home/apt         1 bath    (1000, 2000]
# 18229  Entire home/apt         1 bath    (1000, 2000]
# 18230  Entire home/apt         1 bath    (1000, 2000]
#
# [18231 rows x 5 columns]

# %% [markdown]
# Taking vectorizer from sklearn. Using it do split data into documents and calculate TF and IDF and make vectors from each documents.

# %%
documents = selection_df['neighbourhood_cleansed'] + " " + selection_df['property_type'] + ' ' + selection_df['room_type'] + ' ' + selection_df['bathrooms_text'] + ' ' + selection_df['price_intervals'].astype(str)
documents
# Out:
# 0        Indre By Private room in rental unit Private r...
# 1        Amager st Entire rental unit Entire home/apt 1...
# 2        Amager Vest Entire rental unit Entire home/apt...
# 3        Vesterbro-Kongens Enghave Entire condo Entire ...
# 4        Vesterbro-Kongens Enghave Entire condo Entire ...
#                                ...
# 18226    Vesterbro-Kongens Enghave Entire rental unit E...
# 18227    Frederiksberg Entire rental unit Entire home/a...
# 18228    Amager Vest Entire rental unit Entire home/apt...
# 18229    Vesterbro-Kongens Enghave Entire rental unit E...
# 18230    Nørrebro Entire rental unit Entire home/apt 1 ...
# Length: 18231, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(documents)

# %%
tfidf_matrix.shape
# Out:
# (18231, 72)

# %%
#For computing cosine between vectors
from sklearn.metrics.pairwise import linear_kernel

# %%
def get_recommendations(neighbourhood, property_type, room_type, bathrooms_text, price_interval):
    inputt = neighbourhood + " " + property_type + " " + room_type + " " + bathrooms_text + " " + price_interval
    
    input_vector = tfidf.transform([inputt])

    similarity_scores = linear_kernel(input_vector, tfidf_matrix)

    top_indices = similarity_scores.argsort()[0][::-1][:10]

    top_similar_rental_units = df.iloc[top_indices]
    
    return top_similar_rental_units

# %%
def get_recommendations2(user_input):
    
    input_vector = tfidf.transform([user_input])

    similarity_scores = linear_kernel(input_vector, tfidf_matrix)

    top_indices = similarity_scores.argsort()[0][::-1][:10]

    top_similar_rental_units = df.iloc[top_indices]
    
    return top_similar_rental_units

# %%
pd.set_option("display.max_columns", 40)

# %%
get_recommendations('indre','Private room in rental unit','Private','1','500')
# Out:
#                         id    host_id  host_acceptance_rate host_is_superhost  \
# 17445              8563559   10887109                  99.0                 t
# 15928             14737946   44154045                  47.0                 f
# 1661              39012290    8916473                 100.0                 t
# 15227             20376992   15075072                  99.0                 f
# 5320    866563269205625041  359510710                  26.0                 f
# 10559   894617708996789040  371004204                 100.0                 f
# 86      919613195329293559  494320140                  24.0                 f
# 16061  1024018033019123952  352662638                   0.0                 f
# 16051   971911383594464377  533480916                  97.0                 f
# 12388              5486840   27406722                  78.0                 t
#
#        host_total_listings_count host_has_profile_pic host_identity_verified  \
# 17445                        1.0                    t                      t
# 15928                        4.0                    t                      t
# 1661                         4.0                    t                      t
# 15227                        2.0                    t                      t
# 5320                         1.0                    t                      f
# 10559                        3.0                    t                      f
# 86                           1.0                    t                      t
# 16061                        2.0                    t                      t
# 16051                        5.0                    f                      t
# 12388                        1.0                    t                      t
#
#       neighbourhood_cleansed                property_type     room_type  \
# 17445               Indre By  Private room in rental unit  Private room
# 15928               Indre By  Private room in rental unit  Private room
# 1661                Indre By  Private room in rental unit  Private room
# 15227               Indre By  Private room in rental unit  Private room
# 5320                Indre By  Private room in rental unit  Private room
# 10559               Indre By  Private room in rental unit  Private room
# 86                  Indre By  Private room in rental unit  Private room
# 16061               Indre By  Private room in rental unit  Private room
# 16051               Indre By  Private room in rental unit  Private room
# 12388               Indre By  Private room in rental unit  Private room
#
#        accommodates  bathrooms_text  beds  price  minimum_nights  \
# 17445             2  1 private bath   1.0  523.0               2
# 15928             2  1 private bath   1.0  706.0               5
# 1661              2  1 private bath   1.0  664.0               3
# 15227             3  1 private bath   1.0  428.0               3
# 5320              2  1 private bath   2.0  490.0               3
# 10559             1          1 bath   1.0  529.0               5
# 86                2          1 bath   1.0  800.0               1
# 16061             1          1 bath   1.0  600.0               7
# 16051             2          1 bath   1.0  744.0               1
# 12388             2          1 bath   1.0  550.0               3
#
#        maximum_nights  availability_365  number_of_reviews  \
# 17445            1125               219                315
# 15928              21               170                 65
# 1661             1125                 5                 16
# 15227            1125               140                272
# 5320              365                88                  1
# 10559             365                27                 10
# 86                365               265                  1
# 16061              30                62                  0
# 16051             365               269                  1
# 12388              60                55                103
#
#        review_scores_rating instant_bookable  reviews_per_month  \
# 17445              4.880000                f           3.150000
# 15928              4.780000                f           0.730000
# 1661               5.000000                f           0.320000
# 15227              4.690000                f           3.540000
# 5320               5.000000                f           0.200000
# 10559              4.800000                f           1.670000
# 86                 5.000000                f           0.240000
# 16061              4.818525                f           0.733238
# 16051              5.000000                f           0.290000
# 12388              4.870000                f           1.060000
#
#       price_intervals
# 17445      (500, 800]
# 15928      (500, 800]
# 1661       (500, 800]
# 15227      (200, 500]
# 5320       (200, 500]
# 10559      (500, 800]
# 86         (500, 800]
# 16061      (500, 800]
# 16051      (500, 800]
# 12388      (500, 800]

# %%
get_recommendations('indre','Private','1','shared','1000')
# Out:
#                        id    host_id  host_acceptance_rate host_is_superhost  \
# 0      772195193586734462  139504671             57.000000                 f
# 16338  914975462637560323   40049506             40.000000                 f
# 11099            35839191     178320            100.000000                 f
# 10803            38667633   46445934              0.000000                 f
# 10458            51568169   43947147             71.554308                 f
# 10429            25851499  194237765             71.554308                 f
# 17695  918928139452421475  330805913              0.000000                 f
# 8268             52021443   31741086             60.000000                 f
# 8213             49336526   20053611             71.554308                 f
# 15306  902095588134517281   40049506             40.000000                 f
#
#        host_total_listings_count host_has_profile_pic host_identity_verified  \
# 0                            2.0                    t                      t
# 16338                        3.0                    t                      t
# 11099                        3.0                    t                      t
# 10803                        1.0                    t                      t
# 10458                        2.0                    t                      t
# 10429                        3.0                    t                      t
# 17695                        1.0                    t                      t
# 8268                         2.0                    t                      t
# 8213                         2.0                    t                      t
# 15306                        3.0                    t                      t
#
#       neighbourhood_cleansed                property_type     room_type  \
# 0                   Indre By  Private room in rental unit  Private room
# 16338               Indre By  Private room in rental unit  Private room
# 11099               Indre By  Private room in rental unit  Private room
# 10803               Indre By  Private room in rental unit  Private room
# 10458               Indre By  Private room in rental unit  Private room
# 10429               Indre By  Private room in rental unit  Private room
# 17695               Indre By  Private room in rental unit  Private room
# 8268                Indre By  Private room in rental unit  Private room
# 8213                Indre By  Private room in rental unit  Private room
# 15306               Indre By  Private room in rental unit  Private room
#
#        accommodates bathrooms_text  beds        price  minimum_nights  \
# 0                 2  1 shared bath   1.0  1320.467531               5
# 16338             2  1 shared bath   1.0  1320.467531               5
# 11099             2  1 shared bath   1.0  1320.467531               2
# 10803             2  1 shared bath   1.0  1200.000000               2
# 10458             2  1 shared bath   1.0  1320.467531               2
# 10429             1  1 shared bath   1.0  1320.467531               1
# 17695             2  1 shared bath   1.0  1320.467531               1
# 8268              1  1 shared bath   1.0  1320.467531               2
# 8213              2  1 shared bath   1.0  1320.467531               2
# 15306             1  1 shared bath   1.0  1320.467531               5
#
#        maximum_nights  availability_365  number_of_reviews  \
# 0                  12                 0                  0
# 16338              21                 0                  2
# 11099               7                 0                 23
# 10803               6                87                  2
# 10458            1125                 0                 17
# 10429            1125                 0                 15
# 17695              25                 0                  0
# 8268               16                 0                  3
# 8213              365                 0                  1
# 15306              93                 0                  0
#
#        review_scores_rating instant_bookable  reviews_per_month  \
# 0                  4.818525                f           0.733238
# 16338              4.500000                f           0.370000
# 11099              4.870000                f           0.420000
# 10803              4.000000                f           0.040000
# 10458              5.000000                f           0.590000
# 10429              4.870000                t           0.220000
# 17695              4.818525                f           0.733238
# 8268               5.000000                f           0.110000
# 8213               5.000000                f           0.030000
# 15306              4.818525                f           0.733238
#
#       price_intervals
# 0        (1000, 2000]
# 16338    (1000, 2000]
# 11099    (1000, 2000]
# 10803    (1000, 2000]
# 10458    (1000, 2000]
# 10429    (1000, 2000]
# 17695    (1000, 2000]
# 8268     (1000, 2000]
# 8213     (1000, 2000]
# 15306    (1000, 2000]

# %%
get_recommendations('nørrebro','Private','1','shared','200')
# Out:
#                        id    host_id  host_acceptance_rate host_is_superhost  \
# 17743            49251563   12454263                 100.0                 f
# 17654             1218328    6251797                   0.0                 f
# 11392  773226986315721516    2038200                  89.0                 f
# 16118  982449915176492479  168723549                   0.0                 f
# 4591              7353832   38533050                 100.0                 t
# 7642             33461634  252097959                 100.0                 f
# 9496   818601992672184504   17818905                  82.0                 f
# 14437            23811209     791129                  52.0                 t
# 13591  887461136094251162   31226452                  19.0                 f
# 14047            34835494   13857263                  90.0                 t
#
#        host_total_listings_count host_has_profile_pic host_identity_verified  \
# 17743                        4.0                    t                      t
# 17654                        1.0                    t                      f
# 11392                        3.0                    t                      t
# 16118                       11.0                    t                      t
# 4591                         2.0                    t                      f
# 7642                         2.0                    t                      t
# 9496                         2.0                    t                      t
# 14437                        6.0                    t                      t
# 13591                        4.0                    t                      t
# 14047                        1.0                    t                      t
#
#       neighbourhood_cleansed                property_type     room_type  ...  \
# 17743               Nørrebro                 Private room  Private room  ...
# 17654               Nørrebro  Private room in rental unit  Private room  ...
# 11392               Nørrebro  Private room in rental unit  Private room  ...
# 16118               Nørrebro  Private room in rental unit  Private room  ...
# 4591                Nørrebro  Private room in rental unit  Private room  ...
# 7642                Nørrebro  Private room in rental unit  Private room  ...
# 9496                Nørrebro  Private room in rental unit  Private room  ...
# 14437               Nørrebro  Private room in rental unit  Private room  ...
# 13591               Nørrebro  Private room in rental unit  Private room  ...
# 14047               Nørrebro  Private room in rental unit  Private room  ...
#
#        beds  price  minimum_nights  maximum_nights  availability_365  \
# 17743   1.0  444.0              30             100                31
# 17654   1.0  500.0               1            1125                56
# 11392   1.0  321.0               4              90                20
# 16118   1.0  500.0               1             365               269
# 4591    1.0  474.0               4              30                15
# 7642    1.0  385.0               2              14                30
# 9496    1.0  500.0               1             365               162
# 14437   1.0  319.0              30            1125                31
# 13591   1.0  400.0               3             365                50
# 14047   1.0  300.0               1              30                45
#
#        number_of_reviews  review_scores_rating  instant_bookable  \
# 17743                 19              4.630000                 f
# 17654                191              4.800000                 f
# 11392                  2              4.500000                 f
# 16118                  0              4.818525                 f
# 4591                  24              4.830000                 f
# 7642                  45              4.670000                 f
# 9496                  10              4.300000                 f
# 14437                 12              4.920000                 f
# 13591                  4              5.000000                 f
# 14047                178              4.780000                 f
#
#        reviews_per_month price_intervals
# 17743           0.660000      (200, 500]
# 17654           1.480000      (200, 500]
# 11392           2.000000      (200, 500]
# 16118           0.733238      (200, 500]
# 4591            0.260000      (200, 500]
# 7642            0.850000      (200, 500]
# 9496            0.950000      (200, 500]
# 14437           0.170000      (200, 500]
# 13591           0.550000      (200, 500]
# 14047           3.180000      (200, 500]
#
# [10 rows x 22 columns]

# %%
get_recommendations2("indre by price 1000")
# Out:
#                         id    host_id  host_acceptance_rate host_is_superhost  \
# 16154             19755571   26302109             25.000000                 f
# 5651              50306346    9480538            100.000000                 f
# 11547   857230985895207321   19614750             47.000000                 f
# 16904   910173855396155528  140752313             60.000000                 f
# 6037    923725784314896500  522509674            100.000000                 f
# 5090    894535740374605667  311940082             67.000000                 f
# 13252   957171981556580049   63479454              0.000000                 f
# 14887             26509594  199375729              0.000000                 f
# 10124  1005583309077889843    2786061             88.000000                 f
# 17090               528914    2598525             71.554308                 f
#
#        host_total_listings_count host_has_profile_pic host_identity_verified  \
# 16154                        1.0                    t                      t
# 5651                         2.0                    t                      t
# 11547                        1.0                    t                      t
# 16904                        1.0                    t                      t
# 6037                         1.0                    f                      t
# 5090                         1.0                    t                      t
# 13252                        1.0                    t                      t
# 14887                        1.0                    t                      f
# 10124                        1.0                    t                      t
# 17090                        3.0                    t                      t
#
#       neighbourhood_cleansed property_type        room_type  accommodates  \
# 16154               Indre By   Entire home  Entire home/apt             2
# 5651                Indre By   Entire home  Entire home/apt             6
# 11547               Indre By   Entire home  Entire home/apt             2
# 16904               Indre By   Entire home  Entire home/apt             4
# 6037                Indre By   Entire home  Entire home/apt             6
# 5090                Indre By   Entire home  Entire home/apt             4
# 13252               Indre By   Entire home  Entire home/apt             5
# 14887               Indre By   Entire home  Entire home/apt             5
# 10124               Indre By   Entire home  Entire home/apt             4
# 17090               Indre By   Entire home  Entire home/apt             5
#
#       bathrooms_text  beds        price  minimum_nights  maximum_nights  \
# 16154         1 bath   2.0  1500.000000               3              20
# 5651          1 bath   4.0  1629.000000               3              42
# 11547         1 bath   1.0  1750.000000               3             365
# 16904         1 bath   1.0  1999.000000               2              15
# 6037          1 bath   6.0  2000.000000               5              12
# 5090          1 bath   3.0  1750.000000               3             365
# 13252         1 bath   5.0  1800.000000               3            1125
# 14887         1 bath   5.0  1400.000000               4            1125
# 10124         1 bath   2.0  1029.000000               2              30
# 17090         1 bath   4.0  1320.467531               5              99
#
#        availability_365  number_of_reviews  review_scores_rating  \
# 16154                83                  9              5.000000
# 5651                  2                 11              4.730000
# 11547                78                  6              5.000000
# 16904               364                  3              4.330000
# 6037                 76                  0              4.818525
# 5090                164                  3              5.000000
# 13252                 0                  0              4.818525
# 14887                 0                  2              5.000000
# 10124                 1                 12              4.670000
# 17090                 0                 10              5.000000
#
#       instant_bookable  reviews_per_month price_intervals
# 16154                f           0.120000    (1000, 2000]
# 5651                 f           0.370000    (1000, 2000]
# 11547                f           0.790000    (1000, 2000]
# 16904                f           0.720000    (1000, 2000]
# 6037                 f           0.733238    (1000, 2000]
# 5090                 f           0.470000    (1000, 2000]
# 13252                f           0.733238    (1000, 2000]
# 14887                f           0.030000    (1000, 2000]
# 10124                f           6.670000    (1000, 2000]
# 17090                f           0.070000    (1000, 2000]
